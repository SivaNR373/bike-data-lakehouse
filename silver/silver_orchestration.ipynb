# %%
dbutils.notebook.run(
    "/Workspace/Users/sivanagaraju373@gmail.com/bike-data-lakehouse/silver/crm/silver_crm_cust_info",
    0
)

# %%
dbutils.notebook.run(
    "/Workspace/Users/sivanagaraju373@gmail.com/bike-data-lakehouse/silver/crm/silver_crm_prd_info",
    0
)

# %%
dbutils.notebook.run(
    "/Workspace/Users/sivanagaraju373@gmail.com/bike-data-lakehouse/silver/crm/silver_crm_sales_details",
    0
)

# %%
dbutils.notebook.run(
    "/Workspace/Users/sivanagaraju373@gmail.com/bike-data-lakehouse/silver/erp/silver_erp_cust_az12",
    0
)

# %%
dbutils.notebook.run(
    "/Workspace/Users/sivanagaraju373@gmail.com/bike-data-lakehouse/silver/erp/silver_erp_loc_a101",
    0
)

# %%
dbutils.notebook.run(
    "/Workspace/Users/sivanagaraju373@gmail.com/bike-data-lakehouse/silver/erp/silver_erp_px_cat_g1v2",
    0
)
