# %%
dbutils.notebook.run(
    "/Workspace/Users/sivanagaraju373@gmail.com/bike-data-lakehouse/gold/dim_customers",
    0
)

# %%
dbutils.notebook.run(
    "/Workspace/Users/sivanagaraju373@gmail.com/bike-data-lakehouse/gold/dim_products",
    0
)

# %%
dbutils.notebook.run(
    "/Workspace/Users/sivanagaraju373@gmail.com/bike-data-lakehouse/gold/fact_sales",
    0
)
